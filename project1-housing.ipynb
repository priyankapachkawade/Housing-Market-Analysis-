# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Ames_Housing_Subset.csv',index_col=0)
df
# Out:
#           Neighborhood  Year Built  Overall Qual Kitchen Qual Exter Qual  \
# PID
# 526301100        NAmes        1960             6           TA         TA
# 526350040        NAmes        1961             5           TA         TA
# 526351010        NAmes        1958             6           Gd         TA
# 526353030        NAmes        1968             7           Ex         Gd
# 527105010      Gilbert        1997             5           TA         TA
# ...                ...         ...           ...          ...        ...
# 923275080      Mitchel        1984             6           TA         TA
# 923276100      Mitchel        1983             5           TA         TA
# 923400125      Mitchel        1992             5           TA         TA
# 924100070      Mitchel        1974             5           TA         TA
# 924151050      Mitchel        1993             7           TA         TA
#
#            Lot Area  SalePrice
# PID
# 526301100     31770     215000
# ...

# %%
#disply first 5 rows of the data set
df.head()
# Out:
#           Neighborhood  Year Built  Overall Qual Kitchen Qual Exter Qual  \
# PID
# 526301100        NAmes        1960             6           TA         TA
# 526350040        NAmes        1961             5           TA         TA
# 526351010        NAmes        1958             6           Gd         TA
# 526353030        NAmes        1968             7           Ex         Gd
# 527105010      Gilbert        1997             5           TA         TA
#
#            Lot Area  SalePrice
# PID
# 526301100     31770     215000
# 526350040     11622     105000
# 526351010     14267     172000
# 526353030     11160     244000
# 527105010     13830     189900

# %%
#display last 10 rows of data set
df.tail(10)
# Out:
#           Neighborhood  Year Built  Overall Qual Kitchen Qual Exter Qual  \
# PID
# 923228310      MeadowV        1970             4           TA         TA
# 923229110      Mitchel        1976             6           TA         TA
# 923230040      Mitchel        1976             5           TA         TA
# 923250060      Mitchel        1977             5           TA         TA
# 923251180      Mitchel        1960             5           TA         TA
# 923275080      Mitchel        1984             6           TA         TA
# 923276100      Mitchel        1983             5           TA         TA
# 923400125      Mitchel        1992             5           TA         TA
# 924100070      Mitchel        1974             5           TA         TA
# 924151050      Mitchel        1993             7           TA         TA
#
#            Lot Area  SalePrice
# PID
# 923228310      1894      71000
# 923229110     12640     150900
# 923230040      9297     188000
# ...

# %%
#to sea rows and colum
df.shape
# Out:
# (2930, 7)

# %%
#to read text file
with open('Ames_Housing_Subset_Feature_Description.txt','r')as f:
    print(f.read())
# Out:
# PID: Property ID of the house
#
# Neighborhood: Physical locations within Ames city limits
#
#        Blmngtn	Bloomington Heights
#        Blueste	Bluestem
#        BrDale	Briardale
#        BrkSide	Brookside
#        ClearCr	Clear Creek
#        CollgCr	College Creek
#        Crawfor	Crawford
#        Edwards	Edwards
#        Gilbert	Gilbert
#        IDOTRR	Iowa DOT and Rail Road
#        MeadowV	Meadow Village
#        Mitchel	Mitchell
#        Names	North Ames
#        NoRidge	Northridge
#        NPkVill	Northpark Villa
#        NridgHt	Northridge Heights
#        NWAmes	Northwest Ames
#        OldTown	Old Town
#        SWISU	South & West of Iowa State University
#        Sawyer	Sawyer
#        SawyerW	Sawyer West
#        Somerst	Somerset
#        StoneBr	Stone Brook
#        Timber	Timberland
#        Veenker	Veenker
#
# Year Built: Original construction date
#
# Overall Qual: Rates the overall material and finish of the house
#
#        10	Very Excellent
#        9	Excellent
# ...

# %%
#display index
df.index
# Out:
# Index([526301100, 526350040, 526351010, 526353030, 527105010, 527105030,
#        527127150, 527145080, 527146030, 527162130,
#        ...
#        923228310, 923229110, 923230040, 923250060, 923251180, 923275080,
#        923276100, 923400125, 924100070, 924151050],
#       dtype='int64', name='PID', length=2930)

# %%
#to display columns
df.columns
# Out:
# Index(['Neighborhood', 'Year Built', 'Overall Qual', 'Kitchen Qual',
#        'Exter Qual', 'Lot Area', 'SalePrice'],
#       dtype='object')

# %%
# to sea the info about tables
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2930 entries, 526301100 to 924151050
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Neighborhood  2930 non-null   object
#  1   Year Built    2930 non-null   int64
#  2   Overall Qual  2930 non-null   int64
#  3   Kitchen Qual  2930 non-null   object
#  4   Exter Qual    2930 non-null   object
#  5   Lot Area      2930 non-null   int64
#  6   SalePrice     2930 non-null   int64
# dtypes: int64(4), object(3)
# memory usage: 183.1+ KB

# %%
#to see there is any null 
df.isnull().sum()
# Out:
# Neighborhood    0
# Year Built      0
# Overall Qual    0
# Kitchen Qual    0
# Exter Qual      0
# Lot Area        0
# SalePrice       0
# dtype: int64

# %%
#her neighborhood mai kitne ghar bne hai
plt.figure(figsize=(6,4))
sns.countplot(data=df,x='Neighborhood',color='pink')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Houses')
plt.xticks(rotation=90)
plt.show()
plt.savefig('housing plot.jpeg',format='jpeg')

# %%
#check a min and max value of year built
#subse pehla ghar 1872 mai bna or or latest 2010 mai bna tha
print(df['Year Built'].min())
print(df['Year Built'].max())
# Out:
# 1872
# 2010

# %%
print(df['SalePrice'].mean())
print(df['SalePrice'].median())
print(df['SalePrice'].mode())
# Out:
# 180796.0600682594
# 160000.0
# 0    135000
# Name: SalePrice, dtype: int64

# %%
# creat a histogram of the 'year built' feature  and also showing the mean and median
sns.histplot(data=df, x='Year Built',color='orange',edgecolor='yellow')
plt.vlines(x=df['Year Built'].mean(),ymin=0,ymax=575,colors='b',label='Mean')
plt.vlines(x=df['Year Built'].median(),ymin=0,ymax=575,colors='k',label='Median')
plt.vlines(x=df['Year Built'].mode(),ymin=0,ymax=575,colors='r',label='Mode')
plt.show()

# %%
sns.histplot(data=df,x='SalePrice',color='orange',edgecolor='yellow')
plt.vlines(x=df['SalePrice'].mean(),ymin=0,ymax=325,colors='b',label='mean')
plt.vlines(x=df['SalePrice'].median(),ymin=0,ymax=325,colors='k',label='median')
plt.vlines(x=df['SalePrice'].mode(),ymin=0,ymax=325,colors='r',label='mode')
plt.show()

# %% [markdown]
# 1)box plot for year built<br>
# 2)check max and min of sale price<br>
# 3)range of sale price<br>
# 4)create a histogram of sale price also showing mean , median , and mode<br>
# 5)box plot for sale price<br>
# 6)create a histogram , box plot of lot area also showing maen ,median,and mode<br>
# 7)scatter plot of lot area and sale price<br>
# 8)create a new feature (coloum)in the data to contain ratio of "saleprice" and"lot area"features <br>
# 9)

# %%
#box plot for year built
import seaborn as sns
import matplotlib.pyplot as plt

#sns.boxplot(data=df,x='Year Built')
#plt.show()


#plt.boxplot(df['Year Built'])
#plt.show()


import matplotlib.pyplot as plt

plt.boxplot(df['Year Built'])
plt.xlabel('Year Built')  # Adding a label for clarity
plt.ylabel('Values')      # Optional: Adding a label for the y-axis
plt.title('Boxplot of Year Built')  # Optional: Adding a title
plt.show()

# %%
#check max and min of sale price
print(df['SalePrice'].min())
print(df['SalePrice'].max())
# Out:
# 12789
# 755000

# %%
import pandas as pd
min_price = df['SalePrice'].min()
max_price = df['SalePrice'].max()

print(f"The range of sale prices is from {min_price} to {max_price}.")
# Out:
# The range of sale prices is from 12789 to 755000.

# %%
sns.boxplot(x=df['SalePrice'])
plt.xlabel('SalePrice')  # Adding a label for clarity
plt.title('Boxplot of Sale Price')  # Optional: Adding a title
plt.show()

# %%
# create the histogram for lot area
sns.histplot(data=df,x='Lot Area',color='orange',edgecolor='yellow')
plt.vlines(x=df['Lot Area'].mean(),ymin=0,ymax=350,color='b',label='mean')
plt.vlines(x=df['Lot Area'].median(),ymin=0,ymax=350,color='k',label='median')
plt.vlines(x=df['Lot Area'].mode(),ymin=0,ymax=350,color='r',label='mode')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Create the scatter plot
plt.figure(figsize=(6, 3))
plt.scatter(df['Lot Area'], df['SalePrice'])

# Add labels and title
plt.xlabel('area')
plt.ylabel('price')
plt.title('scatter plot')
plt.show()

# %%
# Assuming df is your DataFrame
# Example of loading a DataFrame
# df = pd.read_csv('your_data.csv')

# Creating a new column 'PriceLotAreaRatio' with the ratio of SalesPrice to LotArea
df['PriceLotAreaRatio'] = df['SalePrice'] / df['Lot Area']

# Display the first few rows to check the new column
print(df.head())
# Out:
#           Neighborhood  Year Built  Overall Qual Kitchen Qual Exter Qual  \
# PID
# 526301100        NAmes        1960             6           TA         TA
# 526350040        NAmes        1961             5           TA         TA
# 526351010        NAmes        1958             6           Gd         TA
# 526353030        NAmes        1968             7           Ex         Gd
# 527105010      Gilbert        1997             5           TA         TA
#
#            Lot Area  SalePrice  PriceLotAreaRatio
# PID
# 526301100     31770     215000           6.767391
# 526350040     11622     105000           9.034590
# 526351010     14267     172000          12.055793
# 526353030     11160     244000          21.863799
# 527105010     13830     189900          13.731020

# %%
price_of_per_area=(df['SalePrice']/df['Lot Area'])
price_of_per_area
# Out:
# PID
# 526301100     6.767391
# 526350040     9.034590
# 526351010    12.055793
# 526353030    21.863799
# 527105010    13.731020
#                ...
# 923275080    17.953887
# 923276100    14.743950
# 923400125    12.642467
# 924100070    16.983017
# 924151050    19.528410
# Length: 2930, dtype: float64

# %%
#create a histogram of the price per area feature and also showing the mean and the median
sns.histplot(data=df,x='PriceLotAreaRatio',color='orange',edgecolor='yellow')
plt.vlines(x=df['PriceLotAreaRatio'].mean(),ymin=0,ymax=350,color='b',label='mean')
plt.vlines(x=df['PriceLotAreaRatio'].median(),ymin=0,ymax=350,color='k',label='median')
plt.vlines(x=df['PriceLotAreaRatio'].mode(),ymin=0,ymax=350,color='r',label='mode')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt

# Create the scatter plot between Lot Area and Price per Lot Area Ratio
plt.figure(figsize=(6, 3))
plt.scatter(df['Lot Area'], df['PriceLotAreaRatio'], color='purple')  # Corrected color

# Add labels and title
plt.xlabel('Lot Area')
plt.ylabel('Price per Lot Area')
plt.title('Scatter Plot of Lot Area vs. Price per Lot Area')

# Show plot
plt.show()

# %%
df.columns
# Out:
# Index(['Neighborhood', 'Year Built', 'Overall Qual', 'Kitchen Qual',
#        'Exter Qual', 'Lot Area', 'SalePrice', 'PriceLotAreaRatio'],
#       dtype='object')

# %%
# Drop the 'PriceLotAreaRatio' column from the DataFrame
df = df.drop('PriceLotAreaRatio', axis=1)

# %%
df.columns
# Out:
# Index(['Neighborhood', 'Year Built', 'Overall Qual', 'Kitchen Qual',
#        'Exter Qual', 'Lot Area', 'SalePrice'],
#       dtype='object')

# %%
df
# Out:
#           Neighborhood  Year Built  Overall Qual Kitchen Qual Exter Qual  \
# PID
# 526301100        NAmes        1960             6           TA         TA
# 526350040        NAmes        1961             5           TA         TA
# 526351010        NAmes        1958             6           Gd         TA
# 526353030        NAmes        1968             7           Ex         Gd
# 527105010      Gilbert        1997             5           TA         TA
# ...                ...         ...           ...          ...        ...
# 923275080      Mitchel        1984             6           TA         TA
# 923276100      Mitchel        1983             5           TA         TA
# 923400125      Mitchel        1992             5           TA         TA
# 924100070      Mitchel        1974             5           TA         TA
# 924151050      Mitchel        1993             7           TA         TA
#
#            Lot Area  SalePrice
# PID
# 526301100     31770     215000
# ...

# %%
df_cleaned = df.drop(columns=['Neighborhood', 'Kitchen Qual', 'Exter Qual'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df_cleaned is your DataFrame after dropping the specified columns

# Create a heatmap of the correlation matrix with annotations
plt.figure(figsize=(10, 8))  # Adjust the figure size as needed
sns.heatmap(df_cleaned.corr(), annot=True, cmap='coolwarm')

# Add title
plt.title('Correlation Matrix Heatmap')

# Show plot
plt.show()

# %%
# sub plot
x=np.array([0,1,2,3])
y1=np.array([3,8,1,10])
y2=np.array([10,20,30,40])

fig,axs=plt.subplots(1,2,figsize=(6,3)) # here 1 means 1 row and 2 is column always row no is first
axs[0].plot(x,y1,'r')
axs[1].plot(x,y2,'b')
plt.tight_layout()
plt.show()

# %%
sns.set_style('darkgrid')

# %%
#plt.figure(figsize=(8,4))
plt.suptitle('collection of subplot')
# plot1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,2,1)
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('plot 1')
# plot 2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,2,2)
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('plot 2')
plt.subplots_adjust(hspace=2,wspace=2)
# plot 3
x=np.array([0,1,2,3])
y=np.array([30,80,100,40])
plt.subplot(2,2,3)
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('plot 3')
           
x=np.array([0,1,2,3])
y=np.array([50,60,70,80])
plt.subplot(2,2,4)
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('plot 4')
plt.tight_layout()
plt.savefig('subplots.jpeg')
plt.show()

# %%
#displot

# %%
#.text make a function to add labels for x,y ( x and y are the argument 
# for every x y is label for x using plt.text
import matplotlib.pyplot as plt

def add_labels(x_values, y_values, labels):
    """
    Add labels next to each point on a plot.

    Parameters:
    - x_values: List or array of x coordinates.
    - y_values: List or array of y coordinates.
    - labels: List or array of labels corresponding to each (x, y) pair.

    Returns:
    - None (plots the points with labels).
    """
    # Check if the lengths of x_values, y_values, and labels are the same
    if len(x_values) != len(y_values) or len(x_values) != len(labels):
        raise ValueError("Lengths of x_values, y_values, and labels must be the same.")

    # Plot the points
    plt.scatter(x_values, y_values)

    # Add labels for each point
    for x, y, label in zip(x_values, y_values, labels):
        plt.text(x, y, label, fontsize=12, ha='left', va='bottom')

    # Show plot
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title('Plot with Labels')
    plt.grid(True)
    plt.show()

# Example usage:
x_data = [1, 2, 3, 4, 5]
y_data = [10, 20, 15, 25, 30]
labels = ['Point 1', 'Point 2', 'Point 3', 'Point 4', 'Point 5']

add_labels(x_data, y_data, labels)
